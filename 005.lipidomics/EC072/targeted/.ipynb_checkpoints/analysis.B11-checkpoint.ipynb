# %%
import pandas, seaborn, numpy, qnorm

# %%
import sklearn, sklearn.preprocessing, sklearn.decomposition, sklearn.impute
import statsmodels, statsmodels.stats, statsmodels.stats.multitest
import scipy, scipy.stats

# %%
import matplotlib, matplotlib.pyplot
matplotlib.rcParams.update({'font.size':20, 
                            'font.family':'sans-serif', 
                            'xtick.labelsize':16, 
                            'ytick.labelsize':16, 
                            'figure.figsize':(16*(2/3), 9*(2/3)), 
                            'axes.labelsize':20
                           })

# %% [markdown]
# # get data

# %%
# path https://reiknistofnun.sharepoint.com/sites/rolfssonlaboratorycommon-hi/Shared%20Documents/General/Projects/Endotheliomics/Alexia/EC-072%20catecholamine-mets/LIPIDOMICS_TARGETED

# %%
inputfile = 'EC_72_lipidomic_targeted_12102024.xlsx'

# %% [markdown]
# # read data

# %%
df = pandas.read_excel(inputfile)
df
# Out:
#                            ID Experiment        Type  Injection order Mode  \
# 0                95_Pool_Pool       EC72  Lipidomics               95  POS
# 1     97_5 uM epi:nor_072-153       EC72  Lipidomics               97  POS
# 2             98_TNFa_072-156       EC72  Lipidomics               98  POS
# 3         99_5 uM nor_072-150       EC72  Lipidomics               99  POS
# 4    100_5 uM epi:nor_072-138       EC72  Lipidomics              100  POS
# ..                        ...        ...         ...              ...  ...
# 151       402_5 uM epi_072-43       EC72  Lipidomics              402  POS
# 152       403_5 uM nor_072-61       EC72  Lipidomics              403  POS
# 153           404_TNFa_072-51       EC72  Lipidomics              404  POS
# 154           405_TNFa_072-53       EC72  Lipidomics              405  POS
# 155             407_Pool_Pool       EC72  Lipidomics              407  POS
#
#     Sample ID     Treatment  TIME  Experiment  BATCH  ...  \
# 0        Pool          Pool   NaN            2  B2_1  ...
# 1     072-153  5 uM epi:nor  24.0            2  B2_1  ...
# 2     072-156          TNFa  24.0            2  B2_1  ...
# 3     072-150      5 uM nor  24.0            2  B2_1  ...
# 4     072-138  5 uM epi:nor   4.0            2  B2_1  ...
# ..        ...           ...   ...          ...   ...  ...
# 151    072-43      5 uM epi   4.0            1  B1_2  ...
# 152    072-61      5 uM nor  24.0            1  B1_2  ...
# 153    072-51          TNFa   4.0            1  B1_2  ...
# 154    072-53          TNFa   4.0            1  B1_2  ...
# 155      Pool          Pool   NaN            1  B1_2  ...
#
#      Compound 142:  Lanosterol fragment +H-H2O  \
# 0                                      136.372
# 1                                        8.710
# 2                                      104.516
# 3                                       85.775
# 4                                      140.757
# ..                                         ...
# 151                                     59.353
# 152                                    222.137
# 153                                    199.398
# 154                                    284.417
# 155                                    412.915
#
#      Compound 143:  Lanosterol fragment +H-H2O off Cholesterol esters  \
# 0                                              254.441
# 1                                                3.332
# 2                                              273.187
# 3                                              192.175
# 4                                             1009.222
# ..                                                 ...
# 151                                             59.353
# 152                                            222.137
# 153                                            199.398
# 154                                            284.417
# 155                                            412.915
#
#      Compound 144:  CE 12:0 +H-H2O  Compound 145:  CE 14:0 +H-H2O  \
# 0                           40.392                        121.166
# 1                          108.898                        102.777
# 2                           28.950                        148.117
# 3                          144.414                        105.133
# 4                          568.578                        388.709
# ..                             ...                            ...
# 151                         13.344                         23.718
# 152                         58.233                         15.116
# 153                         47.213                        125.114
# 154                         56.332                         90.531
# 155                        101.178                        137.852
#
#      Compound 146:  CE 14:1 +H-H2O  Compound 149:  CE 16:1+H-H2O  \
# 0                           20.620                         5.030
# 1                           15.813                        12.504
# 2                           34.765                        38.504
# 3                           36.961                        25.145
# 4                          272.210                        71.240
# ..                             ...                           ...
# 151                          7.066                         6.551
# 152                         64.905                         0.791
# 153                         76.041                         4.701
# 154                         81.664                        29.060
# 155                         49.147                        10.527
#
#      Compound 150:  CE 16:2 +H-H20  Compound 151:  CE 18:0 +H-H2O  \
# 0                          130.945                          1.281
# 1                            8.496                          8.608
# 2                          182.226                          1.372
# 3                          134.718                          1.909
# 4                          758.354                          1.582
# ..                             ...                            ...
# 151                         21.018                          3.316
# 152                        119.737                          5.045
# 153                        154.373                          0.459
# 154                        237.837                          0.205
# 155                        281.821                          1.362
#
#      Compound 152:  CE 18:1 +H-H2O  Compound 153:  CE 18:2 +H-H2O
# 0                            6.623                          7.072
# 1                            0.749                          1.232
# 2                            1.700                          1.313
# 3                            2.164                          1.697
# 4                            3.233                          4.835
# ..                             ...                            ...
# 151                          0.464                          1.383
# 152                          1.323                            NaN
# 153                          2.722                            NaN
# 154                          1.294                          3.435
# 155                          4.624                          5.307
#
# [156 rows x 136 columns]

# %%
batches = list(df['BATCH'].unique())
batches.sort()
batches
# Out:
# ['B1_1', 'B1_2', 'B2_1', 'B2_2']

# %%
selected_batch = 'B1_1'

# %%
bdf = df[df['BATCH'] == selected_batch]
bdf0 = bdf[bdf['Treatment'] == 'Pool']
bdf1 = bdf[bdf['Treatment'] != 'Pool']
bdf0
# Out:
#                 ID Experiment        Type  Injection order Mode Sample ID  \
# 78   283_POOL_POOL       EC72  Lipidomics              283  POS      Pool
# 86   293_POOL_POOL       EC72  Lipidomics              293  POS      Pool
# 94   303_POOL_POOL       EC72  Lipidomics              303  POS      Pool
# 102  313_POOL_POOL       EC72  Lipidomics              313  POS      Pool
# 110  323_POOL_POOL       EC72  Lipidomics              323  POS      Pool
# 116  331_POOL_POOL       EC72  Lipidomics              331  POS      Pool
#
#     Treatment  TIME  Experiment  BATCH  ...  \
# 78       Pool   NaN            1  B1_1  ...
# 86       Pool   NaN            1  B1_1  ...
# 94       Pool   NaN            1  B1_1  ...
# 102      Pool   NaN            1  B1_1  ...
# 110      Pool   NaN            1  B1_1  ...
# 116      Pool   NaN            1  B1_1  ...
#
#      Compound 142:  Lanosterol fragment +H-H2O  \
# 78                                      72.938
# 86                                     447.473
# 94                                      97.457
# 102                                    429.703
# 110                                    341.739
# 116                                    489.218
#
#      Compound 143:  Lanosterol fragment +H-H2O off Cholesterol esters  \
# 78                                             233.045
# 86                                            1674.923
# 94                                             168.502
# 102                                           1111.049
# 110                                           1257.043
# 116                                           1226.893
#
#      Compound 144:  CE 12:0 +H-H2O  Compound 145:  CE 14:0 +H-H2O  \
# 78                          41.443                        351.629
# 86                         558.644                       2152.232
# 94                          10.148                        251.448
# 102                        176.727                       2907.301
# 110                        466.065                        299.884
# 116                        133.950                       2565.654
#
#      Compound 146:  CE 14:1 +H-H2O  Compound 149:  CE 16:1+H-H2O  \
# 78                          22.830                        71.540
# 86                         927.729                       493.964
# 94                          43.380                         4.871
# 102                        347.962                        25.985
# 110                        864.063                        36.851
# 116                        339.495                       210.457
#
#      Compound 150:  CE 16:2 +H-H20  Compound 151:  CE 18:0 +H-H2O  \
# 78                         135.208                          1.934
# 86                        4063.468                          4.808
# 94                          79.680                          0.237
# 102                       2120.937                          2.621
# 110                       3507.578                          3.616
# 116                       1771.206                         10.900
#
#      Compound 152:  CE 18:1 +H-H2O  Compound 153:  CE 18:2 +H-H2O
# 78                           9.253                         20.036
# 86                           5.840                          4.682
# 94                           2.619                            NaN
# 102                          4.420                          9.640
# 110                          5.147                          9.937
# 116                          1.889                         19.729
#
# [6 rows x 136 columns]

# %%
new = bdf0.drop(['ID', 'Experiment', 'Experiment ', 'Type', 'Mode', 'Sample ID', 'Treatment', 'TIME', 'BATCH'], axis=1) # oh yes, Experiment and Experiment 
new.set_index('Injection order', inplace=True)
new2 = new.transpose()
log10new2 = numpy.log10(new2)

# %% [markdown]
# # Data visualization before QN

# %%
seaborn.set_style("white")
g = seaborn.violinplot(data=log10new2, cut=0, bw_method='scott', bw_adjust=1/2, density_norm='area', color='white', common_norm=True)
g.set(ylabel='log$_{10}$ Intensity', xlabel='Pools', title='Pools B11 before QN')
matplotlib.pyplot.grid(ls=':', color='black', alpha=1/2)
matplotlib.pyplot.tight_layout()
matplotlib.pyplot.show()

# %%
qndf = qnorm.quantile_normalize(log10new2, axis=1)

# %%
g = seaborn.violinplot(data=qndf, cut=0, bw_method='scott', bw_adjust=1/2, density_norm='area', color='white', common_norm=True)
g.set(ylabel='log$_{10}$ Intensity', xlabel='Pools', title='Pools B11 after QN')
matplotlib.pyplot.grid(ls=':', color='black', alpha=1/2)
matplotlib.pyplot.tight_layout()
matplotlib.pyplot.show()

# %%
new = bdf1.drop(['ID', 'Experiment', 'Experiment ', 'Type', 'Mode', 'Sample ID', 'Treatment', 'TIME', 'BATCH'], axis=1) # oh yes
new.set_index('Injection order', inplace=True)
new2 = new.transpose()
log10new2 = numpy.log10(new2)

# %%
seaborn.set_style("white")
g = seaborn.violinplot(data=log10new2, cut=0, bw_method='scott', bw_adjust=1/2, density_norm='area', color='white', common_norm=True)
g.set(ylabel='log$_{10}$ Intensity', xlabel='Biological samples', title='Biologicals B11 before QN')
matplotlib.pyplot.grid(ls=':', color='black', alpha=1/2)
tk = g.get_xticklabels()
g.set_xticklabels(tk, fontsize=10)
matplotlib.pyplot.tight_layout()
matplotlib.pyplot.show()
# Out:
# /var/folders/j2/645ctp717nv8rwbn2dsccyxh0000gn/T/ipykernel_1895/2400321944.py:6: UserWarning: set_ticklabels() should only be used with a fixed number of ticks, i.e. after set_ticks() or using a FixedLocator.
#   g.set_xticklabels(tk, fontsize=10)

# %%
qndf = qnorm.quantile_normalize(log10new2, axis=1)

# %%
seaborn.set_style("white")
g = seaborn.violinplot(data=qndf, cut=0, bw_method='scott', bw_adjust=1/2, density_norm='area', color='white', common_norm=True)
g.set(ylabel='log$_{10}$ Intensity', xlabel='Biological samples', title='Biologicals B11 after QN')
matplotlib.pyplot.grid(ls=':', color='black', alpha=1/2)
tk = g.get_xticklabels()
g.set_xticklabels(tk, fontsize=10)
matplotlib.pyplot.tight_layout()
matplotlib.pyplot.show()
# Out:
# /var/folders/j2/645ctp717nv8rwbn2dsccyxh0000gn/T/ipykernel_1895/3355774818.py:6: UserWarning: set_ticklabels() should only be used with a fixed number of ticks, i.e. after set_ticks() or using a FixedLocator.
#   g.set_xticklabels(tk, fontsize=10)

# %% [markdown]
# # Work with both biologicals and pools

# %%
new = bdf.drop(['ID', 'Experiment', 'Experiment ', 'Type', 'Mode', 'Sample ID', 'Treatment', 'TIME', 'BATCH'], axis=1) # oh yes
new.set_index('Injection order', inplace=True)
new2 = new.transpose()
log10new2 = numpy.log10(new2)

# %%
log10new2
# Out:
# Injection order                          283       285       286       287  \
# Compound 1:  IS_LPC_17:0            2.582038  2.324136  2.083105  1.921025
# Compound 2:  IS_LPC_19:0            3.375634  3.638004  3.465748  3.226828
# Compound 3:  IS_TAG 17:0/17:0/17:0  2.477432  2.719286  2.434371  2.578220
# Compound 6:  IS_PC_17:0/17:0        3.519605  4.217164  4.439377  3.611158
# Compound 7:  IS_PC_19:0/19:0        2.974484  3.936548  2.956337  3.154892
# ...                                      ...       ...       ...       ...
# Compound 149:  CE 16:1+H-H2O        1.854549  1.925487  1.758299  1.703575
# Compound 150:  CE 16:2 +H-H20       2.131002  2.900723  2.323493  2.329662
# Compound 151:  CE 18:0 +H-H2O       0.286456  0.812178  0.210586  0.388101
# Compound 152:  CE 18:1 +H-H2O       0.966283  0.957368  0.625210 -0.403403
# Compound 153:  CE 18:2 +H-H2O       1.301811  0.937217  0.809156  0.968530
#
# Injection order                          288       289       290       291  \
# Compound 1:  IS_LPC_17:0            2.079427  1.555433  2.745463  1.699326
# Compound 2:  IS_LPC_19:0            3.439758  3.017869  3.916388  2.812269
# Compound 3:  IS_TAG 17:0/17:0/17:0  2.471689  3.306014  2.744570  2.698057
# Compound 6:  IS_PC_17:0/17:0        3.832954  3.453715  4.163701  3.790701
# Compound 7:  IS_PC_19:0/19:0        3.313024  2.957617  3.874903  2.843715
# ...                                      ...       ...       ...       ...
# Compound 149:  CE 16:1+H-H2O        1.597860 -0.061480  0.473341  0.078094
# Compound 150:  CE 16:2 +H-H20       2.593276  2.747722  2.781813  2.931886
# Compound 151:  CE 18:0 +H-H2O       0.001734 -0.793174  0.693111  0.659346
# Compound 152:  CE 18:1 +H-H2O       0.615950  0.312812  0.842921 -0.079355
# Compound 153:  CE 18:2 +H-H2O       1.193431  0.653791       NaN -0.287350
#
# Injection order                          293       295  ...       319  \
# Compound 1:  IS_LPC_17:0            2.651180  3.153981  ...  2.557881
# Compound 2:  IS_LPC_19:0            3.995513  4.308930  ...  4.117974
# Compound 3:  IS_TAG 17:0/17:0/17:0  3.509010  3.988530  ...  3.559643
# Compound 6:  IS_PC_17:0/17:0        4.394068  4.939963  ...  4.558268
# Compound 7:  IS_PC_19:0/19:0        3.945790  4.752559  ...  4.501189
# ...                                      ...       ...  ...       ...
# Compound 149:  CE 16:1+H-H2O        2.693695  1.154424  ...  2.271447
# Compound 150:  CE 16:2 +H-H20       3.608897  2.044669  ...  2.746199
# Compound 151:  CE 18:0 +H-H2O       0.681964  0.671543  ...  1.064495
# Compound 152:  CE 18:1 +H-H2O       0.766413  1.369717  ...  1.016114
# Compound 153:  CE 18:2 +H-H2O       0.670431  1.687359  ...  1.507896
#
# Injection order                          320       321       323       325  \
# Compound 1:  IS_LPC_17:0            2.521963  2.470203  2.787454  2.750457
# Compound 2:  IS_LPC_19:0            3.789728  3.611884  4.141860  4.208458
# Compound 3:  IS_TAG 17:0/17:0/17:0  3.594779  3.503616  3.649675  2.608466
# Compound 6:  IS_PC_17:0/17:0        4.439341  4.131076  4.450850  3.737743
# Compound 7:  IS_PC_19:0/19:0        3.983777  3.817489  4.027867  3.210518
# ...                                      ...       ...       ...       ...
# Compound 149:  CE 16:1+H-H2O        2.555190  1.763885  1.566449 -0.052076
# Compound 150:  CE 16:2 +H-H20       3.580571  3.674776  3.545007  3.601436
# Compound 151:  CE 18:0 +H-H2O       0.863858  0.514282  0.558228  0.256718
# Compound 152:  CE 18:1 +H-H2O       1.073938  0.058805  0.711554  0.003891
# Compound 153:  CE 18:2 +H-H2O       0.591065  1.013301  0.997255  0.278982
#
# Injection order                          326       327       328       329  \
# Compound 1:  IS_LPC_17:0            2.739992  1.988153  1.908501  2.137259
# Compound 2:  IS_LPC_19:0            4.346043  3.158193  3.204213  3.279408
# Compound 3:  IS_TAG 17:0/17:0/17:0  2.460180  2.351704  3.375537  2.273337
# Compound 6:  IS_PC_17:0/17:0        3.676018  3.806528  3.343440  3.575423
# Compound 7:  IS_PC_19:0/19:0        3.526242  3.315959  2.509289  2.948715
# ...                                      ...       ...       ...       ...
# Compound 149:  CE 16:1+H-H2O        0.175802  0.555940  2.522816  1.059639
# Compound 150:  CE 16:2 +H-H20       1.750323  2.331065  3.641626  2.315160
# Compound 151:  CE 18:0 +H-H2O      -0.126679  0.444045  0.942157  0.747955
# Compound 152:  CE 18:1 +H-H2O            NaN  0.405858  0.287802  0.048442
# Compound 153:  CE 18:2 +H-H2O       0.411620 -0.097453  1.166252  0.663418
#
# Injection order                          331
# Compound 1:  IS_LPC_17:0            2.794588
# Compound 2:  IS_LPC_19:0            3.379938
# Compound 3:  IS_TAG 17:0/17:0/17:0  3.585665
# Compound 6:  IS_PC_17:0/17:0        3.363918
# Compound 7:  IS_PC_19:0/19:0        2.781472
# ...                                      ...
# Compound 149:  CE 16:1+H-H2O        2.323163
# Compound 150:  CE 16:2 +H-H20       3.248269
# Compound 151:  CE 18:0 +H-H2O       1.037426
# Compound 152:  CE 18:1 +H-H2O       0.276232
# Compound 153:  CE 18:2 +H-H2O       1.295105
#
# [126 rows x 39 columns]

# %%
seaborn.set_style("white")
g = seaborn.violinplot(data=log10new2, cut=0, bw_method='scott', bw_adjust=1/2, density_norm='area', color='white', common_norm=True)
g.set(ylabel='log$_{10}$ Intensity', xlabel='All samples', title='All B11 before QN')
matplotlib.pyplot.grid(ls=':', color='black', alpha=1/2)
tk = g.get_xticklabels()
g.set_xticklabels(tk, fontsize=10, rotation=30)

# left are 295, 298, 300, 306, 308, 316
matplotlib.pyplot.plot([9, 12, 14, 18, 20, 26], [-1, -1, -1, -1, -1, -1], 'o', color='skyblue', ms=12, alpha=1/2)

# top are 328, 331 and 325
matplotlib.pyplot.plot([33, 36, 38], [-1, -1, -1], 'o', color='gold', ms=12, alpha=1/2)

matplotlib.pyplot.tight_layout()
matplotlib.pyplot.show()
# Out:
# /var/folders/j2/645ctp717nv8rwbn2dsccyxh0000gn/T/ipykernel_1895/3145370970.py:6: UserWarning: set_ticklabels() should only be used with a fixed number of ticks, i.e. after set_ticks() or using a FixedLocator.
#   g.set_xticklabels(tk, fontsize=10, rotation=30)

# %%
qndf = qnorm.quantile_normalize(log10new2, axis=1)

# %%
seaborn.set_style("white")
g = seaborn.violinplot(data=qndf, cut=0, bw_method='scott', bw_adjust=1/2, density_norm='area', color='white', common_norm=True)
g.set(ylabel='log$_{10}$ Intensity', xlabel='All samples', title='All B11 after QN')
matplotlib.pyplot.grid(ls=':', color='black', alpha=1/2)
tk = g.get_xticklabels()
g.set_xticklabels(tk, fontsize=10)
matplotlib.pyplot.tight_layout()
matplotlib.pyplot.show()
# Out:
# /var/folders/j2/645ctp717nv8rwbn2dsccyxh0000gn/T/ipykernel_1895/695538783.py:6: UserWarning: set_ticklabels() should only be used with a fixed number of ticks, i.e. after set_ticks() or using a FixedLocator.
#   g.set_xticklabels(tk, fontsize=10)

# %% [markdown]
# # do a histogram of intensities

# %%
found_max = 3.75
number_of_bins = 20
print(number_of_bins)

for sample in qndf.columns:
    values = qndf.loc[:, sample]
    #print(sample, len(values), numpy.min(values), numpy.max(values))
        
    hist, bin_edges = numpy.histogram(values, bins=number_of_bins, range=(0, found_max))
    half_bin = (bin_edges[1] - bin_edges[0])/2
    x = bin_edges + half_bin
    x = x[:-1]
    matplotlib.pyplot.plot(x, hist, '.', alpha=1/3, mec='none')

    yhat = scipy.signal.savgol_filter(hist, 11, 3)
    matplotlib.pyplot.plot(x, yhat, '-', lw=2, alpha=1/2)
    
matplotlib.pyplot.xlabel('Abundance [log10 Intensity]')
matplotlib.pyplot.ylabel('Lipid count')
matplotlib.pyplot.grid(ls=':')

matplotlib.pyplot.xlim(-0.1, 3.8)

matplotlib.pyplot.tight_layout()
matplotlib.pyplot.show()
# Out:
# 20

# %%
selected = qndf[(qndf.max(axis=1) >= 1.5) & (qndf.max(axis=1) <= 3)]
print(selected.shape)
print(qndf.shape)

# imputation
imputer = sklearn.impute.KNNImputer(n_neighbors=5)
imputed = imputer.fit_transform(selected)
iselected = pandas.DataFrame(data=imputed, index=selected.index, columns=selected.columns)

transpose = iselected.transpose()
scaled_data = sklearn.preprocessing.StandardScaler().fit_transform(transpose)
model = sklearn.decomposition.PCA(n_components=2)
new = model.fit_transform(scaled_data)
explained = model.explained_variance_ratio_
print(explained)

print(new.shape)
for i in range(len(new)):
    matplotlib.pyplot.scatter(new[i,0], new[i,1], s=666, c='black', marker='o', alpha=1/3, edgecolors='none')
    
    label = iselected.columns[i]
    full_label = df[df['Injection order'] == label]['ID'].values[0]
    matplotlib.pyplot.text(new[i,0], new[i,1], full_label, fontsize=12)
    
matplotlib.pyplot.xlabel('PC1 (exp. var.: {}%)'.format(int(explained[0]*100)))
matplotlib.pyplot.ylabel('PC2 (exp. var.: {}%)'.format(int(explained[1]*100)))
matplotlib.pyplot.grid(alpha=0.5, ls=':')

matplotlib.pyplot.show()
# Out:
# (57, 39)
# (126, 39)
# [0.3088669  0.15814778]
# (39, 2)

# %%
selected = qndf[(qndf.max(axis=1) >= 0) & (qndf.max(axis=1) <= 4)]
print(selected.shape)

# imputation
imputer = sklearn.impute.KNNImputer(n_neighbors=5)
imputed = imputer.fit_transform(selected)
iselected = pandas.DataFrame(data=imputed, index=selected.index, columns=selected.columns)

transpose = iselected.transpose()
scaled_data = sklearn.preprocessing.StandardScaler().fit_transform(transpose)
model = sklearn.decomposition.PCA(n_components=2)
new = model.fit_transform(scaled_data)
explained = model.explained_variance_ratio_
print(explained)

print(new.shape)
for i in range(len(new)):
    
    label = iselected.columns[i]
    full_label = df[df['Injection order'] == label]['ID'].values[0]
    timepoint = df[df['Injection order'] == label]['TIME'].values[0]
                    
    if timepoint == 4:
        the_marker = 'o'
    elif timepoint == 24:
        the_marker = 's'
    elif timepoint == 0:
        the_marker = '.'
    elif numpy.isnan(timepoint) == True:
        the_marker = '*'
        the_color = 'black'
    else:
        print('unmatched', timepoint, type(timepoint))

    if '0uM' in full_label or '0 uM' in full_label:
        the_color = 'black'
    elif 'epi:nor' in full_label:
        the_color = 'tab:red'
    elif 'epi_' in full_label:
        the_color = 'tab:orange'
    elif 'nor_' in full_label:
        the_color = 'purple'
    elif 'TNF' in full_label:
        the_color = 'tab:green'
    else:
        print('unmatched',full_label)

    matplotlib.pyplot.scatter(new[i,0], new[i,1], s=100, c=the_color, marker=the_marker, alpha=1/2, edgecolors='none')

    # add legend
        
matplotlib.pyplot.xlabel('PC1 (exp. var.: {}%)'.format(int(explained[0]*100)))
matplotlib.pyplot.ylabel('PC2 (exp. var.: {}%)'.format(int(explained[1]*100)))
matplotlib.pyplot.grid(alpha=0.5, ls=':')
matplotlib.pyplot.tight_layout()

matplotlib.pyplot.show()
# Out:
# (126, 39)
# [0.33082315 0.15276615]
# (39, 2)
# unmatched 283_POOL_POOL
# unmatched 293_POOL_POOL
# unmatched 303_POOL_POOL
# unmatched 313_POOL_POOL
# unmatched 323_POOL_POOL
# unmatched 331_POOL_POOL

# %% [markdown]
# # DELs

# %%
rules = ((df['Treatment'] == '0 uM') | (df['Treatment'] == '0uM')) & (df['BATCH'] == 'B1_1') & (df['TIME'] == 4) #### ojooooooo BATCH == B11
control_injections = df[rules]['Injection order'].to_list()
print(len(control_injections), control_injections)
rules = (df['Treatment'] == '5 uM epi:nor') & (df['BATCH'] == 'B1_1') & (df['TIME'] == 4)
treated_injections = df[rules]['Injection order'].to_list()
print(len(treated_injections), treated_injections)
# Out:
# 3 [295, 306, 308]
# 3 [285, 287, 296]

# %%
x = []; y = []
p = []
for compound in qndf.index:
    a = qndf.loc[compound, control_injections].values
    b = qndf.loc[compound, treated_injections].values
    results = scipy.stats.ttest_ind(a, b)
    pvalue = results[1]
    if numpy.isnan(pvalue) == True:
        pvalue = 1
    p.append(pvalue)

    value_c = (10**numpy.median(a)) - 1
    value_t = (10**numpy.median(b)) - 1
    diff = numpy.log2(value_t + 1) - numpy.log2(value_c + 1)
    x.append(diff)
    #print(compound, b, a, diff, pvalue)

results = statsmodels.stats.multitest.multipletests(p, alpha=0.05, method='fdr_bh')
adjusted = results[1]
y = -numpy.log10(adjusted)
matplotlib.pyplot.plot(x, y, 'o', color='black')

for i in range(len(adjusted)):
    if adjusted[i] <= 0.05:
        print(i, adjusted[i], x[i], qndf.index[i])

matplotlib.pyplot.axhline(-numpy.log10(0.05), lw=2, color='red', ls='--')
matplotlib.pyplot.axvline(-1, lw=2, color='red', ls='--')
matplotlib.pyplot.axvline(1, lw=2, color='red', ls='--')

matplotlib.pyplot.grid(alpha=0.5, ls=':')
matplotlib.pyplot.xlabel('log2FC')
matplotlib.pyplot.ylabel('-log10 adjusted')
matplotlib.pyplot.tight_layout()

matplotlib.pyplot.show()
# Out:
# 0 0.015438746708789105 -1.8764468806970864 Compound 1:  IS_LPC_17:0
# 15 0.01191383483988197 -1.6578421820290528 Compound 24:  PC 35:1
# 17 0.019237077695290445 -1.3239699207372269 Compound 26:  PC 35:4
# 26 0.015926219146606368 -3.0927285145928325 Compound 35:  PC 37:4
# 28 0.028044433665708905 -1.6075529856893471 Compound 37:  PC 38:3
# 30 0.015926219146606368 -2.3700358133247885 Compound 39:  PC 38:2
# 32 0.04285855568610302 0.6641251609547556 Compound 41:  PC 38:4
# 47 0.01191383483988197 -4.129255507064121 Compound 58:  LPC 16:0
# 48 0.015926219146606368 -2.805058837492851 Compound 60:  LPC 18:0
# 49 0.010823005456294053 -3.521248482946641 Compound 61:  LPC 18:1
# 58 0.029148523707497445 -2.102311949689856 Compound 77:  SM 42:3;O2
# 60 0.015926219146606368 -3.630789202465171 Compound 79:  SM 40:1;O2
# 61 0.01905539947690463 -1.0667103617340121 Compound 80:  SM 42:2;O2
# 63 0.01191383483988197 -1.9613566468147332 Compound 85:  TG 46:1
# 66 0.029148523707497445 -1.5114749350406784 Compound 88:  TG 48:2 NH4
# 67 0.0276534099214592 -1.476031493465313 Compound 89:  TG 48:3
# 68 0.014479712823049988 -1.9525231381764998 Compound 90:  TG 49:0
# 81 0.010823005456294053 5.6684658807602855 Compound 104:  TG 52:5 NH4
# 88 0.030132844169724966 0.9358635512416074 Compound 111:  TG 56:2
# 90 0.019237077695290445 2.307261336940331 Compound 113:  TG 56:4 NH4
# 98 0.03618852836985828 -2.843260282236253 Compound 123:  Cer d18:1/24:0
# 102 0.029148523707497445 4.863837196514026 Compound 128:  DG 34:1 -H2O
# 111 0.01191383483988197 8.971570834287867 Compound 137:  DG 36:4 -H2O
# 116 0.030316144579852718 3.062147920550508 Compound 142:  Lanosterol fragment +H-H2O
# 117 0.01905539947690463 4.005530403832646 Compound 143:  Lanosterol fragment +H-H2O off Cholesterol esters
# 122 0.029148523707497445 2.6410889474775985 Compound 150:  CE 16:2 +H-H20
# 125 0.0276534099214592 -3.1137242587092286 Compound 153:  CE 18:2 +H-H2O

# %% [markdown]
# # show IS as injection order

# %%
for compound in qndf.index:
    if 'IS' in compound:
        print(compound)

        x = qndf.loc[compound, :].index
        y = qndf.loc[compound, :].values

        matplotlib.pyplot.plot(x, y, 'o-', alpha=2/3, mec=None, label=compound)

# left are 295, 298, 300, 306, 308, 316
matplotlib.pyplot.plot([295, 298, 300, 306, 308, 316], [0, 0, 0, 0, 0, 0], '*', color='black')

#matplotlib.pyplot.legend()
matplotlib.pyplot.grid(':', alpha=0.5)
# Out:
# Compound 1:  IS_LPC_17:0
# Compound 2:  IS_LPC_19:0
# Compound 3:  IS_TAG 17:0/17:0/17:0
# Compound 6:  IS_PC_17:0/17:0
# Compound 7:  IS_PC_19:0/19:0
# Compound 9:  IS_SM_d18:1_17:0

# %%
# TODO
### priority
# 
# compute the standar error of pools before and after normalization
# plot IS across injection time with and without normalization
# redo the analysis without normalization
# 
# plot mean  vs sd in lin scale for qn-specific pools and controls before and after qn
# do normalization with is as i did before with all of them and the shift
# dont forget 24h  
# consider doing for other drugs
