# %%
import pandas

import matplotlib, matplotlib.pyplot
matplotlib.rcParams.update({'font.size':20, 'font.family':'FreeSans', 'xtick.labelsize':20, 'ytick.labelsize':20, 'figure.figsize':(12, 8)})

# %%
previous_file = '/home/adrian/projects/vigur/results/sequencing/intersect_previous/supplemetary_information_table_SIT2.DETs.csv'
current_file = '/home/adrian/projects/vigur/results/sequencing/intersect_previous/run_72_treatment_mix_time_four_up.tsv'

# %%
previous = pandas.read_csv(previous_file, sep=',', index_col=0)
print(previous.shape)
previous.head()
# Out:
# (71, 10)
#                     Gene name                             Biotype  \
# ENSEMBL
# ENSG00000258504  RP11-638I2.6                             lincRNA
# ENSG00000228294       BMS1P17  transcribed_unprocessed_pseudogene
# ENSG00000252948    RNU6-1314P                               snRNA
# ENSG00000259109   RP4-687K1.2                processed_pseudogene
# ENSG00000273077  RP11-130C6.1                             lincRNA
#
#                         Description  Base mean  log2FC   P value  \
# ENSEMBL
# ENSG00000258504                 NaN    26.0145  8.0825  0.000007
# ENSG00000228294  BMS1 pseudogene 17    24.3383  7.8918  0.000103
# ENSG00000252948                 NaN    16.6484  7.3430  0.000323
# ENSG00000259109                 NaN    16.2737  7.3119  0.000347
# ENSG00000273077                 NaN    28.7883  7.2419  0.000029
#
#                  Adjusted P-value  Reference expression (TPM)  \
# ENSEMBL
# ENSG00000258504           0.00338                         0.0
# ENSG00000228294           0.03560                         0.0
# ENSG00000252948           0.09160                         0.0
# ENSG00000259109           0.09730                         0.0
# ENSG00000273077           0.01210                         0.0
#
#                  Sample expression (TPM)  Discrete abs(log2FC)
# ENSEMBL
# ENSG00000258504                   2.4715                1.5850
# ENSG00000228294                   6.0061                2.8074
# ENSG00000252948                   3.6135                2.3219
# ENSG00000259109                   3.5709                2.3219
# ENSG00000273077                   5.1682                2.5850

# %%
current = pandas.read_csv(current_file, sep='\t', index_col=0)
print(current.shape)
current.head()
# Out:
# (64, 9)
#                   baseMean  log2FoldChange     lfcSE      stat        pvalue  \
# common
# ENSG00000006128  18.618372        7.743246  0.947880  7.114029  1.127033e-12
# ENSG00000274194   7.039330        6.343128  1.078696  4.953319  7.295814e-07
# ENSG00000277025   7.039330        6.343128  1.078696  4.953319  7.295814e-07
# ENSG00000277733   7.039330        6.343128  1.078696  4.953319  7.295814e-07
# ENSG00000277923   7.039330        6.343128  1.078696  4.953319  7.295814e-07
#
#                          padj    gene_biotype  \
# common
# ENSG00000006128  1.609403e-09  protein_coding
# ENSG00000274194  4.762707e-04  protein_coding
# ENSG00000277025  4.762707e-04  protein_coding
# ENSG00000277733  4.762707e-04  protein_coding
# ENSG00000277923  4.762707e-04  protein_coding
#
#                                                        description hgnc_symbol
# common
# ENSG00000006128  tachykinin precursor 1 [Source:HGNC Symbol;Acc...        TAC1
# ENSG00000274194  membrane bound O-acyltransferase domain contai...         NaN
# ENSG00000277025  membrane bound O-acyltransferase domain contai...         NaN
# ENSG00000277733  membrane bound O-acyltransferase domain contai...         NaN
# ENSG00000277923  membrane bound O-acyltransferase domain contai...         NaN

# %%
intersect = previous.index.intersection(current.index)
print(intersect.shape)
# Out:
# (18,)

# %%
for element in intersect:
    
    gene_name = previous.loc[element, 'Gene name']
    gene_description = previous.loc[element, 'Description']
    print(element, gene_name, gene_description)
    
    x = previous.loc[element, 'log2FC']
    y = current.loc[element, 'log2FoldChange']
    
    matplotlib.pyplot.plot(x, y, 'o', color='black')
    matplotlib.pyplot.text(x+0.05, y+0.05, gene_name, fontsize=15)

matplotlib.pyplot.xlabel('Previous [log2 FC @ 4 h w/ 5 uM]')
matplotlib.pyplot.ylabel('New [log2 FC @ 4 h w/ 5 uM]')
matplotlib.pyplot.xlim(1, 7)
matplotlib.pyplot.ylim(1, 7)
matplotlib.pyplot.grid(':')
# Out:
# ENSG00000023171 GRAMD1B GRAM domain containing 1B
# ENSG00000109321 AREG amphiregulin
# ENSG00000211448 DIO2 iodothyronine deiodinase 2
# ENSG00000198400 NTRK1 neurotrophic receptor tyrosine kinase 1
# ENSG00000172572 PDE3A phosphodiesterase 3A
# ENSG00000027869 SH2D2A SH2 domain containing 2A
# ENSG00000153234 NR4A2 nuclear receptor subfamily 4 group A member 2
# ENSG00000119508 NR4A3 nuclear receptor subfamily 4 group A member 3
# ENSG00000178726 THBD thrombomodulin
# ENSG00000159167 STC1 stanniocalcin 1
# ENSG00000156427 FGF18 fibroblast growth factor 18
# ENSG00000095752 IL11 interleukin 11
# ENSG00000187479 C11orf96 chromosome 11 open reading frame 96
# ENSG00000141404 GNAL G protein subunit alpha L
# ENSG00000108551 RASD1 ras related dexamethasone induced 1
# ENSG00000255112 CHMP1B charged multivesicular body protein 1B
# ENSG00000174343 CHRNA9 cholinergic receptor nicotinic alpha 9 subunit
# ENSG00000095637 SORBS1 sorbin and SH3 domain containing 1

# %%
# only before
for element in previous.index:
    if element not in intersect:
        gene_name = previous.loc[element, 'Gene name']
        gene_description = previous.loc[element, 'Description']
        print(element, gene_name, gene_description)
# Out:
# ENSG00000258504 RP11-638I2.6 nan
# ENSG00000228294 BMS1P17 BMS1 pseudogene 17
# ENSG00000252948 RNU6-1314P nan
# ENSG00000259109 RP4-687K1.2 nan
# ENSG00000273077 RP11-130C6.1 nan
# ENSG00000004799 PDK4 pyruvate dehydrogenase kinase 4
# ENSG00000135346 CGA glycoprotein hormones, alpha polypeptide
# ENSG00000153802 TMPRSS11D transmembrane serine protease 11D
# ENSG00000121966 CXCR4 C-X-C motif chemokine receptor 4
# ENSG00000259423 RP11-265N7.2 nan
# ENSG00000081985 IL12RB2 interleukin 12 receptor subunit beta 2
# ENSG00000109193 SULT1E1 sulfotransferase family 1E member 1
# ENSG00000237649 KIFC1 kinesin family member C1
# ENSG00000272841 RP3-428L16.2 nan
# ENSG00000226935 LINC00161 long intergenic non-protein coding RNA 161
# ENSG00000120875 DUSP4 dual specificity phosphatase 4
# ENSG00000168453 HR HR lysine demethylase and nuclear receptor corepressor
# ENSG00000116761 CTH cystathionine gamma-lyase
# ENSG00000181634 TNFSF15 TNF superfamily member 15
# ENSG00000259276 RP11-815J21.3 nan
# ENSG00000123977 DAW1 dynein assembly factor with WD repeats 1
# ENSG00000271218 RP3-523E19.2 nan
# ENSG00000140519 RHCG Rh family C glycoprotein
# ENSG00000280191 CH507-42P11.5 long intergenic non-protein coding RNA 1669
# ENSG00000154319 FAM167A family with sequence similarity 167 member A
# ENSG00000230024 RP11-95P13.1 nan
# ENSG00000171848 RRM2 ribonucleotide reductase regulatory subunit M2
# ENSG00000030419 IKZF2 IKAROS family zinc finger 2
# ENSG00000127951 FGL2 fibrinogen like 2
# ENSG00000269952 RP11-324I22.3 nan
# ENSG00000003989 SLC7A2 solute carrier family 7 member 2
# ENSG00000146374 RSPO3 R-spondin 3
# ENSG00000185186 LINC00313 long intergenic non-protein coding RNA 313
# ENSG00000163406 SLC15A2 solute carrier family 15 member 2
# ENSG00000028137 TNFRSF1B TNF receptor superfamily member 1B
# ENSG00000138134 STAMBPL1 STAM binding protein like 1
# ENSG00000267279 RP11-879F14.2 nan
# ENSG00000171246 NPTX1 neuronal pentraxin 1
# ENSG00000176641 RNF152 ring finger protein 152
# ENSG00000120833 SOCS2 suppressor of cytokine signaling 2
# ENSG00000166257 SCN3B sodium voltage-gated channel beta subunit 3
# ENSG00000140678 ITGAX integrin subunit alpha X
# ENSG00000144891 AGTR1 angiotensin II receptor type 1
# ENSG00000166971 AKTIP AKT interacting protein
# ENSG00000113448 PDE4D phosphodiesterase 4D
# ENSG00000267165 RP11-78A19.3 nan
# ENSG00000138347 MYPN myopalladin
# ENSG00000107099 DOCK8 dedicator of cytokinesis 8
# ENSG00000095794 CREM cAMP responsive element modulator
# ENSG00000087494 PTHLH parathyroid hormone like hormone
# ENSG00000117461 PIK3R3 phosphoinositide-3-kinase regulatory subunit 3
# ENSG00000173597 SULT1B1 sulfotransferase family 1B member 1
# ENSG00000137269 LRRC1 leucine rich repeat containing 1

# %%
# only now
for element in current.index:
    if element not in intersect:
        gene_name = current.loc[element, 'hgnc_symbol']
        gene_description = current.loc[element, 'description']
        print(element, gene_name, gene_description)
# Out:
# ENSG00000006128 TAC1 tachykinin precursor 1 [Source:HGNC Symbol;Acc:HGNC:11517]
# ENSG00000274194 nan membrane bound O-acyltransferase domain containing 7 [Source:NCBI gene;Acc:79143]
# ENSG00000277025 nan membrane bound O-acyltransferase domain containing 7 [Source:NCBI gene;Acc:79143]
# ENSG00000277733 nan membrane bound O-acyltransferase domain containing 7 [Source:NCBI gene;Acc:79143]
# ENSG00000277923 nan membrane bound O-acyltransferase domain containing 7 [Source:NCBI gene;Acc:79143]
# ENSG00000278322 nan membrane bound O-acyltransferase domain containing 7 [Source:NCBI gene;Acc:79143]
# ENSG00000278519 nan membrane bound O-acyltransferase domain containing 7 [Source:NCBI gene;Acc:79143]
# ENSG00000270672 MTRNR2L6 MT-RNR2 like 6 [Source:HGNC Symbol;Acc:HGNC:37163]
# ENSG00000171551 ECEL1 endothelin converting enzyme like 1 [Source:HGNC Symbol;Acc:HGNC:3147]
# ENSG00000181195 PENK proenkephalin [Source:HGNC Symbol;Acc:HGNC:8831]
# ENSG00000128713 HOXD11 homeobox D11 [Source:HGNC Symbol;Acc:HGNC:5134]
# ENSG00000170369 CST2 cystatin SA [Source:HGNC Symbol;Acc:HGNC:2474]
# ENSG00000179292 TMEM151A transmembrane protein 151A [Source:HGNC Symbol;Acc:HGNC:28497]
# ENSG00000109472 CPE carboxypeptidase E [Source:HGNC Symbol;Acc:HGNC:2303]
# ENSG00000054356 PTPRN protein tyrosine phosphatase, receptor type N [Source:HGNC Symbol;Acc:HGNC:9676]
# ENSG00000119915 ELOVL3 ELOVL fatty acid elongase 3 [Source:HGNC Symbol;Acc:HGNC:18047]
# ENSG00000125848 FLRT3 fibronectin leucine rich transmembrane protein 3 [Source:HGNC Symbol;Acc:HGNC:3762]
# ENSG00000104267 CA2 carbonic anhydrase 2 [Source:HGNC Symbol;Acc:HGNC:1373]
# ENSG00000107859 PITX3 paired like homeodomain 3 [Source:HGNC Symbol;Acc:HGNC:9006]
# ENSG00000187908 DMBT1 deleted in malignant brain tumors 1 [Source:HGNC Symbol;Acc:HGNC:2926]
# ENSG00000163687 DNASE1L3 deoxyribonuclease 1 like 3 [Source:HGNC Symbol;Acc:HGNC:2959]
# ENSG00000165272 AQP3 aquaporin 3 (Gill blood group) [Source:HGNC Symbol;Acc:HGNC:636]
# ENSG00000163497 FEV FEV, ETS transcription factor [Source:HGNC Symbol;Acc:HGNC:18562]
# ENSG00000013588 GPRC5A G protein-coupled receptor class C group 5 member A [Source:HGNC Symbol;Acc:HGNC:9836]
# ENSG00000204099 NEU4 neuraminidase 4 [Source:HGNC Symbol;Acc:HGNC:21328]
# ENSG00000277926 NEU4 neuraminidase 4 [Source:HGNC Symbol;Acc:HGNC:21328]
# ENSG00000171174 RBKS ribokinase [Source:HGNC Symbol;Acc:HGNC:30325]
# ENSG00000183682 BMP8A bone morphogenetic protein 8a [Source:HGNC Symbol;Acc:HGNC:21650]
# ENSG00000174460 ZCCHC12 zinc finger CCHC-type containing 12 [Source:HGNC Symbol;Acc:HGNC:27273]
# ENSG00000275993 SIK1B salt inducible kinase 1B (putative) [Source:HGNC Symbol;Acc:HGNC:52389]
# ENSG00000276600 RAB7B RAB7B, member RAS oncogene family [Source:HGNC Symbol;Acc:HGNC:30513]
# ENSG00000227158 nan ligand of numb-protein X 1, E3 ubiquitin protein ligase pseudogene
# ENSG00000198732 SMOC1 SPARC related modular calcium binding 1 [Source:HGNC Symbol;Acc:HGNC:20318]
# ENSG00000103241 FOXF1 forkhead box F1 [Source:HGNC Symbol;Acc:HGNC:3809]
# ENSG00000186009 ATP4B ATPase H+/K+ transporting subunit beta [Source:HGNC Symbol;Acc:HGNC:820]
# ENSG00000127533 F2RL3 F2R like thrombin or trypsin receptor 3 [Source:HGNC Symbol;Acc:HGNC:3540]
# ENSG00000110675 ELMOD1 ELMO domain containing 1 [Source:HGNC Symbol;Acc:HGNC:25334]
# ENSG00000154734 ADAMTS1 ADAM metallopeptidase with thrombospondin type 1 motif 1 [Source:HGNC Symbol;Acc:HGNC:217]
# ENSG00000119938 PPP1R3C protein phosphatase 1 regulatory subunit 3C [Source:HGNC Symbol;Acc:HGNC:9293]
# ENSG00000119699 TGFB3 transforming growth factor beta 3 [Source:HGNC Symbol;Acc:HGNC:11769]
# ENSG00000108556 CHRNE cholinergic receptor nicotinic epsilon subunit [Source:HGNC Symbol;Acc:HGNC:1966]
# ENSG00000154217 PITPNC1 phosphatidylinositol transfer protein cytoplasmic 1 [Source:HGNC Symbol;Acc:HGNC:21045]
# ENSG00000153815 CMIP c-Maf inducing protein [Source:HGNC Symbol;Acc:HGNC:24319]
# ENSG00000075643 MOCOS molybdenum cofactor sulfurase [Source:HGNC Symbol;Acc:HGNC:18234]
# ENSG00000104419 NDRG1 N-myc downstream regulated 1 [Source:HGNC Symbol;Acc:HGNC:7679]
# ENSG00000074370 ATP2A3 ATPase sarcoplasmic/endoplasmic reticulum Ca2+ transporting 3 [Source:HGNC Symbol;Acc:HGNC:813]
