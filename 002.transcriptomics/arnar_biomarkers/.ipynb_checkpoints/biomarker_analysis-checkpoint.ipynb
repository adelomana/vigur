# %%
import pandas, scipy, numpy, seaborn

import matplotlib, matplotlib.pyplot 
import sklearn, sklearn.cluster
import statsmodels, statsmodels.stats, statsmodels.stats.multitest

# %%
# read biomarkers
df = pandas.read_excel('Endothelialbiomarkers.xlsx')
print(df.shape)
biomarkers = list(set(df['Gene']))
print(len(biomarkers))

for element in biomarkers:
    the_list = list(df['Gene'])
    counter = the_list.count(element)
    if counter > 1:
        print(f'Element {element} is twice')
# Out:
# (70, 6)
# 67
# Element CD40LG is twice
# Element EDN1 is twice
# Element ANGPT2 is twice

# %%
# read annotation
anno_file = '/Users/adrian/software/kallisto/human_index_standard/t2g.txt'
df = pandas.read_csv(anno_file, sep='\t', header=None)

sub = df[df[2].isin(biomarkers)]
match = list(set(sub[1]))
print(len(match))

ensembl_bm = [element.split('.')[0] for element in match]
ensembl_bm.sort()
print(ensembl_bm)
# Out:
# 65
# ['ENSG00000005381', 'ENSG00000007908', 'ENSG00000028137', 'ENSG00000063660', 'ENSG00000076716', 'ENSG00000078401', 'ENSG00000085563', 'ENSG00000090339', 'ENSG00000091879', 'ENSG00000100985', 'ENSG00000102245', 'ENSG00000102265', 'ENSG00000102755', 'ENSG00000103257', 'ENSG00000104368', 'ENSG00000105329', 'ENSG00000105974', 'ENSG00000106366', 'ENSG00000108622', 'ENSG00000109272', 'ENSG00000110799', 'ENSG00000111859', 'ENSG00000112715', 'ENSG00000115884', 'ENSG00000117394', 'ENSG00000117525', 'ENSG00000117601', 'ENSG00000119630', 'ENSG00000120156', 'ENSG00000122861', 'ENSG00000124145', 'ENSG00000126457', 'ENSG00000132693', 'ENSG00000133116', 'ENSG00000133661', 'ENSG00000136244', 'ENSG00000136859', 'ENSG00000137673', 'ENSG00000146070', 'ENSG00000147257', 'ENSG00000153904', 'ENSG00000154188', 'ENSG00000160323', 'ENSG00000162512', 'ENSG00000162692', 'ENSG00000163072', 'ENSG00000163631', 'ENSG00000164283', 'ENSG00000164761', 'ENSG00000164867', 'ENSG00000169429', 'ENSG00000169439', 'ENSG00000171560', 'ENSG00000173391', 'ENSG00000174175', 'ENSG00000178726', 'ENSG00000179399', 'ENSG00000180210', 'ENSG00000181092', 'ENSG00000183098', 'ENSG00000188404', 'ENSG00000213420', 'ENSG00000213722', 'ENSG00000232810', 'ENSG00000261371']
# /var/folders/j2/645ctp717nv8rwbn2dsccyxh0000gn/T/ipykernel_1883/3562909034.py:3: DtypeWarning: Columns (4) have mixed types. Specify dtype option on import or set low_memory=False.
#   df = pandas.read_csv(anno_file, sep='\t', header=None)

# %%
rosetta = {}
for index, row in sub.iterrows():
    gene_name = row[2]
    ensembl = row[1].split('.')[0]
    if gene_name not in rosetta.keys():
        rosetta[ensembl] = gene_name
print(len(rosetta))
print(rosetta)
# Out:
# 65
# {'ENSG00000162512': 'SDC3', 'ENSG00000028137': 'TNFRSF1B', 'ENSG00000117525': 'F3', 'ENSG00000162692': 'VCAM1', 'ENSG00000007908': 'SELE', 'ENSG00000188404': 'SELL', 'ENSG00000174175': 'SELP', 'ENSG00000132693': 'CRP', 'ENSG00000153904': 'DDAH1', 'ENSG00000117601': 'SERPINC1', 'ENSG00000117394': 'SLC2A1', 'ENSG00000122861': 'PLAU', 'ENSG00000133661': 'SFTPD', 'ENSG00000180210': 'F2', 'ENSG00000137673': 'MMP7', 'ENSG00000173391': 'OLR1', 'ENSG00000110799': 'VWF', 'ENSG00000102755': 'FLT1', 'ENSG00000179399': 'GPC5', 'ENSG00000183098': 'GPC6', 'ENSG00000133116': 'KL', 'ENSG00000119630': 'PGF', 'ENSG00000103257': 'SLC7A5', 'ENSG00000261371': 'PECAM1', 'ENSG00000108622': 'ICAM2', 'ENSG00000005381': 'MPO', 'ENSG00000090339': 'ICAM1', 'ENSG00000105329': 'TGFB1', 'ENSG00000126457': 'PRMT1', 'ENSG00000163072': 'NOSTRIN', 'ENSG00000115884': 'SDC1', 'ENSG00000063660': 'GPC1', 'ENSG00000124145': 'SDC4', 'ENSG00000100985': 'MMP9', 'ENSG00000178726': 'THBD', 'ENSG00000181092': 'ADIPOQ', 'ENSG00000163631': 'ALB', 'ENSG00000171560': 'FGA', 'ENSG00000109272': 'PF4V1', 'ENSG00000169429': 'CXCL8', 'ENSG00000164283': 'ESM1', 'ENSG00000078401': 'EDN1', 'ENSG00000111859': 'NEDD9', 'ENSG00000213722': 'DDAH2', 'ENSG00000146070': 'PLA2G7', 'ENSG00000112715': 'VEGFA', 'ENSG00000232810': 'TNF', 'ENSG00000106366': 'SERPINE1', 'ENSG00000213420': 'GPC2', 'ENSG00000164867': 'NOS3', 'ENSG00000105974': 'CAV1', 'ENSG00000085563': 'ABCB1', 'ENSG00000136244': 'IL6', 'ENSG00000164761': 'TNFRSF11B', 'ENSG00000169439': 'SDC2', 'ENSG00000104368': 'PLAT', 'ENSG00000091879': 'ANGPT2', 'ENSG00000154188': 'ANGPT1', 'ENSG00000120156': 'TEK', 'ENSG00000136859': 'ANGPTL2', 'ENSG00000160323': 'ADAMTS13', 'ENSG00000102265': 'TIMP1', 'ENSG00000076716': 'GPC4', 'ENSG00000147257': 'GPC3', 'ENSG00000102245': 'CD40LG'}

# %%
# read expression profiles
inputfile = 'vigur Suppl. Info. Table SIT1 expression profiles.csv'
df = pandas.read_csv(inputfile, sep=',', skiprows=3, index_col='ENSEMBL ID')
df.drop(columns=['Gene name', 'Gene biotype'], inplace=True)
df = df.loc[ensembl_bm, :]
df = df.apply(pandas.to_numeric, errors='coerce')
print(df.shape)
df.head()
# Out:
# (65, 25)
#                  RSS_HLMV_28  RSS_HLMV_29  RSS_HLMV_30  RSS_HLMV_31  \
# ENSEMBL ID
# ENSG00000005381        0.034        0.153        0.000        0.022
# ENSG00000007908        0.345        0.323        0.711       14.540
# ENSG00000028137        2.758        2.854        1.963        1.814
# ENSG00000063660       80.458      106.449       68.305       50.897
# ENSG00000076716        0.472        0.602        0.358        0.431
#
#                  RSS_HLMV_32  RSS_HLMV_33  RSS_HLMV_34  RSS_HLMV_36  \
# ENSEMBL ID
# ENSG00000005381        0.099        0.077        0.041        0.082
# ENSG00000007908       12.582       11.539        2.281        2.134
# ENSG00000028137        3.192        2.404       12.420       12.090
# ENSG00000063660       65.608       67.875       55.656       48.985
# ENSG00000076716        0.527        0.366        0.359        0.324
#
#                  RSS_HLMV_37  RSS_HLMV_38  ...  RSS_HLMV_45  RSS_HLMV_46  \
# ENSEMBL ID                                 ...
# ENSG00000005381        0.081        0.054  ...        0.046        0.000
# ENSG00000007908        1.369        1.116  ...        0.316        0.143
# ENSG00000028137       11.585       13.293  ...        1.667        1.660
# ENSG00000063660       37.844       61.705  ...       55.026       43.677
# ENSG00000076716        0.282        0.185  ...        0.296        0.288
#
#                  RSS_HLMV_47  RSS_HLMV_48  RSS_HLMV_49  RSS_HLMV_50  \
# ENSEMBL ID
# ENSG00000005381        0.039        0.033        0.005        0.008
# ENSG00000007908        0.164        0.291        0.159        0.247
# ENSG00000028137        2.059        2.622        1.579        1.519
# ENSG00000063660       63.687       78.860       49.220       44.720
# ENSG00000076716        0.218        0.202        0.203        0.120
#
#                  RSS_HLMV_51  RSS_HLMV_52  RSS_HLMV_53  RSS_HLMV_54
# ENSEMBL ID
# ENSG00000005381        0.025        0.024        0.040        0.028
# ENSG00000007908        0.122        0.123        0.084        0.277
# ENSG00000028137        2.467        2.041        2.594        3.010
# ENSG00000063660       99.401       61.133       80.048       69.360
# ENSG00000076716        0.142        0.303        0.149        0.162
#
# [5 rows x 25 columns]

# %%
# changing to gene names
df = df.rename(index=rosetta)

# %%
# dropping TNF because is zero expressed
df.drop(labels='TNF', inplace=True)
df.shape
# Out:
# (64, 25)

# %%
# testing significance
sample_groupings = [
    [
        ['RSS_HLMV_34', 'RSS_HLMV_36'],
        ['RSS_HLMV_37', 'RSS_HLMV_38', 'RSS_HLMV_39'],
        ['RSS_HLMV_41', 'RSS_HLMV_42']   
    ],
    [
        ['RSS_HLMV_46', 'RSS_HLMV_47', 'RSS_HLMV_48'],
        ['RSS_HLMV_49', 'RSS_HLMV_50', 'RSS_HLMV_51'],
        ['RSS_HLMV_52', 'RSS_HLMV_53', 'RSS_HLMV_54']
    ]
]
reference_groupings = [
    ['RSS_HLMV_31','RSS_HLMV_32', 'RSS_HLMV_33'],
    ['RSS_HLMV_43', 'RSS_HLMV_44', 'RSS_HLMV_45']
]

pvalues = []
for index, row in df.iterrows():
    #print(index)
    for i in range(2):
        for j in range(3):
            samples = df.loc[index, sample_groupings[i][j]].values
            references = df.loc[index, reference_groupings[i]].values
            [statistic, pvalue] = scipy.stats.ttest_ind(samples, references)
            if numpy.isnan(pvalue):
                print(samples, references, pvalue)
                print('converting to P = 1')
                pvalue = 1
            pvalues.append(pvalue)
            #print(sample_groupings[i][j], samples)
            #print(reference_groupings[i], references)
            #print(pvalue)
            #print()
    #print()

# multiple correction
print(pvalues[:5])
result = statsmodels.stats.multitest.multipletests(pvalues, method='fdr_bh')
print(len(result[0]))

times = ['T4', 'T24']; concentrations = ['half', 'five', 'fifty']
loc = 0
annot_dict = {}
for k in range(len(df.index)):
    for i in range(2):
        for j in range(3):
            loc = k*6 + i*3  + j
            if result[0][loc] == True:
                print(k, df.index[k], loc, times[i], concentrations[j], result[0][loc], result[1][loc])
                annot_dict[(df.index[k], times[i]+concentrations[j])] = '*'
# Out:
# [0. 0.] [0. 0. 0.] nan
# converting to P = 1
# [0. 0. 0.] [0. 0. 0.] nan
# converting to P = 1
# [0. 0.] [0. 0. 0.] nan
# converting to P = 1
# [0. 0.] [0. 0. 0.] nan
# converting to P = 1
# [0. 0. 0.] [0. 0. 0.] nan
# converting to P = 1
# [0. 0. 0.] [0. 0. 0.] nan
# converting to P = 1
# [0. 0. 0.] [0. 0. 0.] nan
# converting to P = 1
# [0. 0. 0.] [0. 0. 0.] nan
# converting to P = 1
# [0.9009946663213896, 0.7206953956242974, 0.37874888275728275, 0.9263774282865006, 0.38610539235553654]
# 384
# 1 SELE 6 T4 half True 0.0363527943953636
# 1 SELE 7 T4 five True 0.019222031028571344
# 1 SELE 8 T4 fifty True 0.03209270756763412
# 2 TNFRSF1B 12 T4 half True 0.019222031028571344
# 2 TNFRSF1B 13 T4 five True 0.03269174848082357
# 5 EDN1 32 T4 fifty True 0.03710062391552482
# 13 SLC7A5 78 T4 half True 0.03269174848082357
# 14 PLAT 87 T24 half True 0.03136793985838436
# 14 PLAT 88 T24 five True 0.007499619294186828
# 14 PLAT 89 T24 fifty True 0.03136793985838436
# 22 VEGFA 132 T4 half True 0.02280381149303175
# 22 VEGFA 133 T4 five True 0.004797111303891988
# 22 VEGFA 134 T4 fifty True 0.03756882557010843
# 24 SLC2A1 144 T4 half True 0.03209270756763412
# 29 PLAU 175 T4 five True 0.03136793985838436
# 29 PLAU 176 T4 fifty True 0.041863520589726796
# 30 SDC4 181 T4 five True 0.02236577683372616
# 35 IL6 211 T4 five True 0.03209270756763412
# 35 IL6 214 T24 five True 0.03136793985838436
# 35 IL6 215 T24 fifty True 0.02236577683372616
# 36 ANGPTL2 217 T4 five True 0.034672511517111745
# 44 VCAM1 264 T4 half True 0.03136793985838436
# 44 VCAM1 265 T4 five True 0.019222031028571344
# 44 VCAM1 266 T4 fifty True 0.03136793985838436
# 47 ESM1 285 T24 half True 0.041863520589726796
# 47 ESM1 287 T24 fifty True 0.019222031028571344
# 50 CXCL8 305 T24 fifty True 0.02236577683372616
# 51 SDC2 311 T24 fifty True 0.041863520589726796
# 55 THBD 330 T4 half True 0.03136793985838436
# 55 THBD 331 T4 five True 3.718725913955931e-05
# 55 THBD 333 T24 half True 0.02236577683372616
# 55 THBD 335 T24 fifty True 0.02280381149303175

# %%
annot_dict
# Out:
# {('SELE', 'T4half'): '*',
#  ('SELE', 'T4five'): '*',
#  ('SELE', 'T4fifty'): '*',
#  ('TNFRSF1B', 'T4half'): '*',
#  ('TNFRSF1B', 'T4five'): '*',
#  ('EDN1', 'T4fifty'): '*',
#  ('SLC7A5', 'T4half'): '*',
#  ('PLAT', 'T24half'): '*',
#  ('PLAT', 'T24five'): '*',
#  ('PLAT', 'T24fifty'): '*',
#  ('VEGFA', 'T4half'): '*',
#  ('VEGFA', 'T4five'): '*',
#  ('VEGFA', 'T4fifty'): '*',
#  ('SLC2A1', 'T4half'): '*',
#  ('PLAU', 'T4five'): '*',
#  ('PLAU', 'T4fifty'): '*',
#  ('SDC4', 'T4five'): '*',
#  ('IL6', 'T4five'): '*',
#  ('IL6', 'T24five'): '*',
#  ('IL6', 'T24fifty'): '*',
#  ('ANGPTL2', 'T4five'): '*',
#  ('VCAM1', 'T4half'): '*',
#  ('VCAM1', 'T4five'): '*',
#  ('VCAM1', 'T4fifty'): '*',
#  ('ESM1', 'T24half'): '*',
#  ('ESM1', 'T24fifty'): '*',
#  ('CXCL8', 'T24fifty'): '*',
#  ('SDC2', 'T24fifty'): '*',
#  ('THBD', 'T4half'): '*',
#  ('THBD', 'T4five'): '*',
#  ('THBD', 'T24half'): '*',
#  ('THBD', 'T24fifty'): '*'}

# %%
# collapse replicates to medians
initial_column_names = df.columns
print(initial_column_names)

df['T4zero'] = numpy.median(df[['RSS_HLMV_31','RSS_HLMV_32', 'RSS_HLMV_33']], axis=1)
df['T4half'] = numpy.median(df[['RSS_HLMV_34', 'RSS_HLMV_36']], axis=1)
df['T4five'] = numpy.median(df[['RSS_HLMV_37', 'RSS_HLMV_38', 'RSS_HLMV_39']], axis=1)
df['T4fifty'] = numpy.median(df[['RSS_HLMV_41', 'RSS_HLMV_42']], axis=1)

df['T24zero'] = numpy.median(df[['RSS_HLMV_43', 'RSS_HLMV_44', 'RSS_HLMV_45']], axis=1)
df['T24half'] = numpy.median(df[['RSS_HLMV_46', 'RSS_HLMV_47', 'RSS_HLMV_48']], axis=1)
df['T24five'] = numpy.median(df[['RSS_HLMV_49', 'RSS_HLMV_50', 'RSS_HLMV_51']], axis=1)
df['T24fifty'] = numpy.median(df[['RSS_HLMV_52', 'RSS_HLMV_53', 'RSS_HLMV_54']], axis=1)

df.drop(columns=initial_column_names, inplace=True)

print(df.shape)
df.head()
# Out:
# Index(['RSS_HLMV_28', 'RSS_HLMV_29', 'RSS_HLMV_30', 'RSS_HLMV_31',
#        'RSS_HLMV_32', 'RSS_HLMV_33', 'RSS_HLMV_34', 'RSS_HLMV_36',
#        'RSS_HLMV_37', 'RSS_HLMV_38', 'RSS_HLMV_39', 'RSS_HLMV_41',
#        'RSS_HLMV_42', 'RSS_HLMV_43', 'RSS_HLMV_44', 'RSS_HLMV_45',
#        'RSS_HLMV_46', 'RSS_HLMV_47', 'RSS_HLMV_48', 'RSS_HLMV_49',
#        'RSS_HLMV_50', 'RSS_HLMV_51', 'RSS_HLMV_52', 'RSS_HLMV_53',
#        'RSS_HLMV_54'],
#       dtype='object')
# (64, 8)
#             T4zero   T4half  T4five  T4fifty  T24zero  T24half  T24five  \
# ENSEMBL ID
# MPO          0.077   0.0615   0.054   0.0345    0.026    0.033    0.008
# SELE        12.582   2.2075   1.369   1.0915    0.151    0.164    0.159
# TNFRSF1B     2.404  12.2550  11.585  10.6495    1.841    2.059    1.579
# GPC1        65.608  52.3205  37.844  46.7330   55.026   63.687   49.220
# GPC4         0.431   0.3415   0.282   0.4465    0.431    0.218    0.142
#
#             T24fifty
# ENSEMBL ID
# MPO            0.028
# SELE           0.123
# TNFRSF1B       2.594
# GPC1          69.360
# GPC4           0.162

# %%
# exclude gene whose max difference is below 10 TPMs
excluding = []
for index, row in df.iterrows():
    floor = row.min()
    ceiling = row.max()
    difference = ceiling - floor
    rel_change = numpy.log2((ceiling+1)/(floor+1))
    
    if difference < 10:
        excluding.append(index)
        print(f'Excluding {index} because difference is {difference}')
    else:
        if rel_change < 1:
            print('\tWARNING', index, difference, numpy.log2(ceiling/floor))

df.drop(labels=excluding, inplace=True)
print(df.shape)
df.head()
# Out:
# Excluding MPO because difference is 0.069
# 	WARNING GPC1 31.516 0.8740393131811838
# Excluding GPC4 because difference is 0.3045
# 	WARNING EDN1 296.6234999999999 0.7196005873101232
# Excluding ABCB1 because difference is 1.8360000000000003
# 	WARNING ANGPT2 10.18 0.5928394927566673
# Excluding MMP9 because difference is 0.074
# Excluding CD40LG because difference is 0.31599999999999995
# 	WARNING TGFB1 25.689 0.7411758223328903
# 	WARNING CAV1 392.01 0.8264531740624497
# 	WARNING SERPINE1 2199.1995000000006 0.5442350061368019
# 	WARNING VWF 14.584499999999991 0.24540135458809964
# 	WARNING NEDD9 41.63699999999999 0.8218622436826784
# Excluding SDC1 because difference is 9.325
# Excluding F3 because difference is 5.674
# Excluding SERPINC1 because difference is 0.317
# 	WARNING PGF 35.759 0.639511690280154
# 	WARNING TEK 16.45300000000001 0.372521742154822
# 	WARNING SDC4 31.927 0.6556955609210708
# 	WARNING PRMT1 42.351 0.762458734659014
# Excluding CRP because difference is 0.151
# Excluding KL because difference is 0.012
# Excluding SFTPD because difference is 0.587
# Excluding ANGPTL2 because difference is 7.6450000000000005
# Excluding MMP7 because difference is 2.2920000000000003
# Excluding PLA2G7 because difference is 0.255
# Excluding GPC3 because difference is 0.0
# 	WARNING DDAH1 15.426499999999997 0.44309826741528247
# Excluding ANGPT1 because difference is 0.5934999999999999
# Excluding ADAMTS13 because difference is 2.0875
# Excluding SDC3 because difference is 9.751000000000001
# Excluding VCAM1 because difference is 1.468
# Excluding NOSTRIN because difference is 0.7030000000000001
# Excluding ALB because difference is 0.121
# Excluding TNFRSF11B because difference is 2.782
# 	WARNING NOS3 11.7345 1.04585890624485
# 	WARNING SDC2 16.823500000000003 0.5432703391067489
# Excluding FGA because difference is 0.0245
# Excluding OLR1 because difference is 0.7364999999999999
# Excluding SELP because difference is 0.278
# Excluding GPC5 because difference is 0.643
# Excluding F2 because difference is 0.08399999999999999
# Excluding ADIPOQ because difference is 0.06799999999999999
# Excluding GPC6 because difference is 0.201
# Excluding SELL because difference is 0.11150000000000003
# Excluding GPC2 because difference is 3.508
# 	WARNING PECAM1 96.05099999999999 0.4134490110462463
# (33, 8)
#              T4zero    T4half   T4five   T4fifty  T24zero  T24half  T24five  \
# ENSEMBL ID
# SELE         12.582    2.2075    1.369    1.0915    0.151    0.164    0.159
# TNFRSF1B      2.404   12.2550   11.585   10.6495    1.841    2.059    1.579
# GPC1         65.608   52.3205   37.844   46.7330   55.026   63.687   49.220
# EDN1        458.654  588.2830  568.980  755.2775  512.746  566.492  629.784
# ICAM1        88.597   70.4325   61.119   58.0425   42.217   31.816   26.774
#
#             T24fifty
# ENSEMBL ID
# SELE           0.123
# TNFRSF1B       2.594
# GPC1          69.360
# EDN1         615.314
# ICAM1         36.742

# %%
zscore_df = df.apply(scipy.stats.zscore, axis=1)
zscore_df.head()
# Out:
#               T4zero    T4half    T4five   T4fifty   T24zero   T24half  \
# ENSEMBL ID
# SELE        2.602863 -0.005878 -0.216724 -0.286504 -0.522999 -0.519730
# TNFRSF1B   -0.702613  1.449032  1.302691  1.098361 -0.825583 -0.777967
# GPC1        1.065012 -0.265854 -1.715809 -0.825493  0.005127  0.872606
# EDN1       -1.566071  0.016379 -0.219263  2.054968 -0.905741 -0.249636
# ICAM1       1.839826  0.927460  0.459661  0.305135 -0.489748 -1.012169
#
#              T24five  T24fifty
# ENSEMBL ID
# SELE       -0.520987 -0.530040
# TNFRSF1B   -0.882808 -0.661113
# GPC1       -0.576398  1.440809
# EDN1        0.523003  0.346360
# ICAM1      -1.265419 -0.764746

# %%
linkage_method = 'average'
distance_metric = 'cosine'

seaborn.clustermap(zscore_df, 
                   cmap='bwr', 
                   col_cluster=True, 
                   row_cluster=True,
                   vmin=-2, vmax=2, 
                   method=linkage_method, 
                   metric=distance_metric, 
                   yticklabels=1, 
                   cbar_kws={'label':'z-score'})

matplotlib.pyplot.show()

# %%
# determine the best partition
x = zscore_df.to_numpy()
k_range = range(2, 8+1)

pvx = []; pvy = []; all_labels = []
for k in k_range:

  kmeans_model = sklearn.cluster.AgglomerativeClustering(n_clusters=k, 
                                                         metric='cosine', linkage='average').fit(x)
  labels = kmeans_model.labels_
  
  ss = sklearn.metrics.silhouette_score(x, labels, metric='cosine') # best value is 1, worst is -1 ergo k=6
  khi = sklearn.metrics.calinski_harabasz_score(x, labels) # higher better ergo 2
  dbi = sklearn.metrics.davies_bouldin_score(x, labels) # lower better ergo 8

  print(k, ss, khi, dbi)
  pvx.append(k)
  pvy.append(ss)
  all_labels.append(labels)

best_partition_index = 4
worst_partition_index = 2

matplotlib.pyplot.plot(pvx, pvy, 'ok')
matplotlib.pyplot.plot(pvx, pvy, ':', color='black')
matplotlib.pyplot.plot([pvx[best_partition_index], pvx[best_partition_index]], [pvy[worst_partition_index], pvy[best_partition_index]], ls='--')

matplotlib.pyplot.grid(alpha=0.5, ls=':')
matplotlib.pyplot.xlabel('number of clusters (k)')
matplotlib.pyplot.ylabel('Silhoutte score')
matplotlib.pyplot.tight_layout()

groupings = all_labels[best_partition_index]
print(groupings)

color_options = ['tab:blue', 'tab:orange', 'tab:green', 'tab:red', 'tab:purple', 'tab:gray']
k_colors = []
for i in range(len(zscore_df.index)):
  k_colors.append(color_options[groupings[i]])
# Out:
# 2 0.41809235995761423 14.30839116971859 1.4150250399804942
# 3 0.3353996573615938 9.115291003813223 1.3246652567705055
# 4 0.3222612903693562 8.786625627514498 1.1459966790140435
# 5 0.3926284155510145 11.265711262645423 1.0810508166470334
# 6 0.4783300984657606 12.895303071514817 0.9268739605601358
# 7 0.43740180422588093 11.428078635434575 0.7888065750342055
# 8 0.40702277144654236 10.474619415970603 0.7346792691291807
# [3 5 1 4 5 2 4 5 5 4 3 1 1 1 1 0 5 5 5 3 2 1 3 1 4 0 4 1 4 5 5 1 2]

# %%
annot = pandas.DataFrame('', index=zscore_df.index, columns=zscore_df.columns)
for (row, col), val in annot_dict.items():
    if row not in zscore_df.index:
        print('bypassing', row)
    else:
        annot.at[row, col] = val
annot
# Out:
# bypassing ANGPTL2
# bypassing VCAM1
# bypassing VCAM1
# bypassing VCAM1
#            T4zero T4half T4five T4fifty T24zero T24half T24five T24fifty
# ENSEMBL ID
# SELE                   *      *       *
# TNFRSF1B               *      *
# GPC1
# EDN1                                  *
# ICAM1
# ANGPT2
# TIMP1
# FLT1
# SLC7A5                 *
# PLAT                                                  *       *        *
# TGFB1
# CAV1
# SERPINE1
# ICAM2
# PF4V1
# VWF
# NEDD9
# VEGFA                  *      *       *
# SLC2A1                 *
# PGF
# TEK
# PLAU                          *       *
# SDC4                          *
# PRMT1
# IL6                           *                               *        *
# DDAH1
# ESM1                                                  *                *
# NOS3
# CXCL8                                                                  *
# SDC2                                                                   *
# THBD                   *      *                       *                *
# DDAH2
# PECAM1

# %%
seaborn.set(font_scale=0.9)

seaborn.clustermap(zscore_df, 
                   annot=annot, fmt='', annot_kws={'va':'center_baseline', 'size':18},
                   cmap='bwr', 
                   col_cluster=False, 
                   row_cluster=True,
                   vmin=-2.5, vmax=2.5, 
                   method=linkage_method, 
                   metric=distance_metric, 
                   yticklabels=1, 
                   cbar_kws={'label':'z-score'}, 
                   row_colors=k_colors)

matplotlib.pyplot.tight_layout()
matplotlib.pyplot.savefig('/Users/adrian/scratch/heatmap.svg')
