# %% [markdown]
# This script reads experimental results derived from EC072 progrenesis analysis.

# %%
Data available is both normalized and raw. Visualize both and decide.

# %%
import pandas

# %% [markdown]
# # user-defined variables

# %%
experiment_one_input_file = '/home/adrian/projects/vigur/data/lipidomics/072/progenesis/HPMVEC_POSB1_1andB1_2.csv'
experiment_two_input_file = '/home/adrian/projects/vigur/data/lipidomics/072/progenesis/HPMVEC_POSB2_1andB2_2.csv'

# %% [markdown]
# # read information

# %%
df = pandas.read_csv(experiment_one_input_file)
df.shape
# Out:
# (494, 209)

# %% [markdown]
# # manipulate data

# %%
## check that index is unique

# %%
print(df['Unnamed: 0'].shape)
print(len(list(set(df['Unnamed: 0']))))
# Out:
# (494,)

# %%
df.rename(columns={'Unnamed: 0': 'uniqueID'}, inplace=True)
df
# Out:
#              uniqueID         Unnamed: 1        Unnamed: 2 Unnamed: 3  \
# 0                 NaN                NaN               NaN        NaN
# 1            Compound  Neutral mass (Da)               m/z     Charge
# 2    4.32_600.2622m/z                NaN  600.262199185733          1
# 3    2.17_319.1463m/z                NaN  319.146338165776          1
# 4    2.29_300.9931m/z                NaN  300.993055791382          1
# ..                ...                ...               ...        ...
# 489  4.35_571.3446m/z                NaN  571.344633754983          1
# 490  5.43_452.3433m/z                NaN  452.343293857851          1
# 491  4.32_483.3659m/z                NaN  483.365851450019          1
# 492  8.19_563.4591m/z                NaN  563.459121111676          1
# 493    5.95_530.4041n    530.40412949134   531.41140592334          1
#
#                Unnamed: 4                        Unnamed: 5       Unnamed: 6  \
# 0                     NaN                               NaN              NaN
# 1    Retention time (min)  Chromatographic peak width (min)  Identifications
# 2        4.31853333333333                0.0648500000000007                0
# 3                 2.17235                 0.205816666666667                0
# 4        2.28628333333333                 0.249516666666667                0
# ..                    ...                               ...              ...
# 489      4.34556666666667                0.0977333333333332                0
# 490      5.42981666666667                 0.119366666666666                0
# 491               4.32395                 0.146366666666666                0
# 492               8.18795                 0.162583333333332                0
# 493                  5.95                 0.249516666666667                0
#
#             Unnamed: 7         Unnamed: 8        Unnamed: 9  ...  \
# 0                  NaN                NaN               NaN  ...
# 1            Anova (p)            q Value   Max Fold Change  ...
# 2                    0                  0  38373.8519466977  ...
# 3                    0                  0  6885.37637814429  ...
# 4                    0                  0  3725.86445734503  ...
# ..                 ...                ...               ...  ...
# 489  0.999999933338617  0.999999999994059  5.82596175866323  ...
# 490  0.999999955383498  0.999999999994059  6.37798634969464  ...
# 491  0.999999957212986  0.999999999994059  9.60395849231868  ...
# 492  0.999999970070085  0.999999999994059  3.44301086850698  ...
# 493   0.99999999628984  0.999999999994059   13.194045239698  ...
#
#              Unnamed: 199          Unnamed: 200 Unnamed: 201 Unnamed: 202  \
# 0                     NaN                   NaN          NaN          NaN
# 1    Accepted Compound ID  Accepted Description      Adducts      Formula
# 2                     NaN                   NaN          NaN          NaN
# 3                     NaN                   NaN          NaN          NaN
# 4                     NaN                   NaN          NaN          NaN
# ..                    ...                   ...          ...          ...
# 489                   NaN                   NaN          NaN          NaN
# 490                   NaN                   NaN          NaN          NaN
# 491                   NaN                   NaN          NaN          NaN
# 492                   NaN                   NaN          NaN          NaN
# 493                   NaN                   NaN    M+H, M+Na          NaN
#
#     Unnamed: 203         Unnamed: 204      Unnamed: 205        Unnamed: 206  \
# 0            NaN                  NaN               NaN                 NaN
# 1          Score  Fragmentation Score  Mass Error (ppm)  Isotope Similarity
# 2            NaN                  NaN               NaN                 NaN
# 3            NaN                  NaN               NaN                 NaN
# 4            NaN                  NaN               NaN                 NaN
# ..           ...                  ...               ...                 ...
# 489          NaN                  NaN               NaN                 NaN
# 490          NaN                  NaN               NaN                 NaN
# 491          NaN                  NaN               NaN                 NaN
# 492          NaN                  NaN               NaN                 NaN
# 493          NaN                  NaN               NaN                 NaN
#
#                     Unnamed: 207   Unnamed: 208
# 0                            NaN            NaN
# 1    Retention Time Error (mins)  Compound Link
# 2                            NaN            NaN
# 3                            NaN            NaN
# 4                            NaN            NaN
# ..                           ...            ...
# 489                          NaN            NaN
# 490                          NaN            NaN
# 491                          NaN            NaN
# 492                          NaN            NaN
# 493                          NaN            NaN
#
# [494 rows x 209 columns]

# %%
 We have raw and normalized abundances. Plot and decide
