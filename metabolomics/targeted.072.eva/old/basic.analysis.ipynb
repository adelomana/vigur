# %% [markdown]
# The conclusion of this analysis are
# - ISs are different across batches.
# - within a batch, an IS can vary a bit less than an order of magnitud, therefore not reliable.
#
# A new strategy is devised:
# - per batch, QN. Then z-score. Is there something across conditions?

# %%
import pandas, numpy

# %%
import matplotlib, matplotlib.pyplot
matplotlib.rcParams.update({'font.size':20, 
                            'xtick.labelsize':20, 
                            'ytick.labelsize':20, 
                            'axes.labelsize':20, 
                            'figure.figsize':(12 * 0.6, 9 * 0.6)})

# %%
# define profile of injections across batches for ISs. start with ISs and their corresponding metabolites

# %%
input_data_file = '/Users/adrian/gd15/research/vigur/data/targeted.2024.eva/EC_72_EVA_All_ION_MODES.xlsx'

# %% [markdown]
# # read information

# %% [markdown]
# ## sample list

# %%
samplelist = pandas.read_excel(input_data_file, sheet_name='Sample list Alexia', skiprows=1, index_col=0)
samplelist
# Out:
#            Experiment  Timepoint     Treatment  Rep M/R/C  \
# Sample ID
# 072-36              1          0          0 µM    1     C
# 072-37              1          0          0 µM    2     C
# 072-38              1          0          0 µM    3     C
# 072-39              1          4           0µM    1     C
# 072-40              1          4           0µM    2     C
# ...               ...        ...           ...  ...   ...
# 072-244             3         24  5 µM epi:nor    2     C
# 072-245             3         24  5 µM epi:nor    3     C
# 072-246             3         24          TNFa    1     C
# 072-247             3         24          TNFa    2     C
# 072-248             3         24          TNFa    3     C
#
#            Total cells per well  Unnamed: 7  Unnamed: 8  Unnamed: 9  \
# Sample ID
# 072-36                 248000.0         NaN         NaN         NaN
# 072-37                 248000.0         NaN         NaN         NaN
# 072-38                 248000.0         NaN         NaN         NaN
# 072-39                 257000.0         NaN         NaN         NaN
# 072-40                 257000.0         NaN         NaN         NaN
# ...                         ...         ...         ...         ...
# 072-244                340000.0         NaN         NaN         NaN
# 072-245                340000.0         NaN         NaN         NaN
# 072-246                313000.0         NaN         NaN         NaN
# 072-247                313000.0         NaN         NaN         NaN
# 072-248                313000.0         NaN         NaN         NaN
#
#            Sample list from alexia
# Sample ID
# 072-36                         NaN
# 072-37                         NaN
# 072-38                         NaN
# 072-39                         NaN
# 072-40                         NaN
# ...                            ...
# 072-244                        NaN
# 072-245                        NaN
# 072-246                        NaN
# 072-247                        NaN
# 072-248                        NaN
#
# [99 rows x 10 columns]

# %%
basicdf = pandas.read_excel(input_data_file, sheet_name='BASIC_NEG', index_col='SAMPLE')
basicdf
# Out:
#                               Sample  SHOT ORDER  \
# SAMPLE
# Pool                            Pool           1
# 072-48     NEG_072-48_5 µM epi:nor_4           2
# 072-52             NEG_072-52_TNFa_4           3
# 072-50     NEG_072-50_5 µM epi:nor_4           4
# 072-59        NEG_072-59_5 µM epi_24           5
# ...                              ...         ...
# 072-220            NEG_072-220_0µM_4         121
# 072-237      NEG_072-237_5 µM epi_24         122
# 072-244  NEG_072-244_5 µM epi:nor_24         123
# 072-228   NEG_072-228_5 µM epi:nor_4         124
# Pool                            Pool         125
#
#          LCMS_BATCH_Biological_replicate     TREATMENT  TIME  Cell Count  \
# SAMPLE
# Pool                                   1           NaN   NaN         NaN
# 072-48                                 1  5 µM epi:nor   4.0    167000.0
# 072-52                                 1          TNFa   4.0    226000.0
# 072-50                                 1  5 µM epi:nor   4.0    167000.0
# 072-59                                 1      5 µM epi  24.0    249000.0
# ...                                  ...           ...   ...         ...
# 072-220                                3           0µM   4.0    280000.0
# 072-237                                3      5 µM epi  24.0    331000.0
# 072-244                                3  5 µM epi:nor  24.0    340000.0
# 072-228                                3  5 µM epi:nor   4.0    317000.0
# Pool                                   3           NaN   NaN         NaN
#
#          Technical replicate  Alanine IS   AMP IS  Citrate IS  ...  \
# SAMPLE                                                         ...
# Pool                     NaN     865.404   69.021    1057.016  ...
# 072-48                   1.0       0.473  226.107      93.586  ...
# 072-52                   2.0       0.634   68.874     101.881  ...
# 072-50                   3.0       0.907  466.702      49.439  ...
# 072-59                   3.0       0.331  265.049      36.159  ...
# ...                      ...         ...      ...         ...  ...
# 072-220                  2.0    1166.587    0.000    3338.140  ...
# 072-237                  1.0    1146.403    2.487    3073.513  ...
# 072-244                  2.0     839.499    0.000    1936.300  ...
# 072-228                  1.0    1263.497    0.000    4045.342  ...
# Pool                     NaN     560.810  166.955    1892.240  ...
#
#          Phosphoenolpyruvate  erythrose 4-phosphate  Citrate  \
# SAMPLE
# Pool                  52.040                 41.523  237.663
# 072-48                82.744                 77.874  157.720
# 072-52                30.406                 38.643  269.912
# 072-50                 4.890                 54.335  290.670
# 072-59                15.888                 34.069  715.790
# ...                      ...                    ...      ...
# 072-220               84.229                157.158  355.825
# 072-237               39.044                 40.321  499.329
# 072-244               31.896                 12.872  243.476
# 072-228               48.238                 79.559  380.073
# Pool                  33.408                 51.892  287.249
#
#          hydroxyglutarate  Aspartate  glycerol phosphate  Adrenaline  \
# SAMPLE
# Pool              713.870    260.327              35.492     264.610
# 072-48            116.584    468.921               8.897     283.618
# 072-52             21.599     58.803               1.495      65.873
# 072-50            100.339    471.287              11.992     306.999
# 072-59            148.353    231.172              11.981     127.805
# ...                   ...        ...                 ...         ...
# 072-220          1636.135    690.943              67.524     494.379
# 072-237          1883.490    313.692             164.787     504.568
# 072-244           757.205    213.700              11.635     107.549
# 072-228          1707.917    825.967              42.550     559.027
# Pool              728.601    385.191              25.695     261.010
#
#          Niacinamide  Tyrosine  N-acetyl Glutamate
# SAMPLE
# Pool         572.353    75.170              72.749
# 072-48         0.000    91.716             184.931
# 072-52         0.000    14.736              19.691
# 072-50        23.383    84.216             154.960
# 072-59         0.000    39.444             114.604
# ...              ...       ...                 ...
# 072-220      917.419   168.979              53.133
# 072-237      874.164   153.535              60.082
# 072-244      701.609    21.406              45.572
# 072-228     1032.240   252.534              63.002
# Pool         338.138   119.832              44.692
#
# [125 rows x 65 columns]

# %%
color_map = {'5 µM epi:nor':'tab:red', 
            'TNFa':'tab:green',
            '5 µM epi':'tab:orange',
            '5 µM nor':'tab:purple',
            '0µM':'tab:blue',
            '0 µM':'tab:blue'}

for label in basicdf.index:
    if type(label) == str:
        if 'oo' not in label:
            treatment = samplelist.loc[label, 'Treatment']
            the_color = color_map[treatment]
        else:
            the_color = 'black'
    else:
        the_color = 'black'

# %%
iss = [element for element in basicdf.columns if 'IS' in element]

for standard in iss:
    
    for id in basicdf.index:
        a = basicdf.loc[id, 'SHOT ORDER']
        b = basicdf.loc[id, standard] + 1
        # define color
        if type(id) == str:
            if 'oo' not in id:
                treatment = samplelist.loc[id, 'Treatment']
                the_color = color_map[treatment]
            else:
                the_color = 'black'
        else:
            the_color = 'black'
        # plot
        matplotlib.pyplot.semilogy(a, b, 'o', label=standard, ms=8, alpha=2/3, mew=0, color=the_color)

    # add batch borders: 39.5 and 81.5 are batch transition points
    matplotlib.pyplot.axvline(x=39.5, color='black', ls=':', lw=1)
    matplotlib.pyplot.axvline(x=81.5, color='black', ls=':', lw=1)

    legend_elements = [
        matplotlib.lines.Line2D([0], [0], color='black', marker='o', 
                                markeredgecolor='white', markersize=10, alpha=2/3, ls='None'),
        matplotlib.lines.Line2D([0], [0], color='tab:red', marker='o', markeredgecolor='white', 
                                markersize=10, alpha=2/3, ls='None'),
        matplotlib.lines.Line2D([0], [0], color='tab:orange', marker='o', markeredgecolor='white', 
                                markersize=10, alpha=2/3, ls='None'),
        matplotlib.lines.Line2D([0], [0], color='tab:purple', marker='o', markeredgecolor='white', 
                                markersize=10, alpha=2/3, ls='None'),
        matplotlib.lines.Line2D([0], [0], color='tab:blue', marker='o', markeredgecolor='white', 
                                markersize=10, alpha=2/3, ls='None')

    ]
    matplotlib.pyplot.legend(legend_elements, ['Pool', 'Mix', 'Epi', 'Nor', 'CTL'], bbox_to_anchor=(1.05, 1), loc='upper left')
    
    matplotlib.pyplot.title(standard)
    matplotlib.pyplot.xlabel('Injection rank')
    matplotlib.pyplot.ylabel('log$_2$ (Intensity+1)')
    matplotlib.pyplot.grid(alpha=0.5, ls=':')
    matplotlib.pyplot.show()
