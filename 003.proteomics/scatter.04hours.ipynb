# %%
import pandas, numpy

# %%
import matplotlib, matplotlib.pyplot
matplotlib.rcParams.update({'font.size':20, 
                            'font.family':'sans-serif', 
                            'xtick.labelsize':16, 
                            'ytick.labelsize':16, 
                            'figure.figsize':(16*(2/3), 9*(2/3)), 
                            'axes.labelsize':20
                           })

# %%
input_file = '../002.transcriptomics/supplemetary_information_table_SIT2.DETs.xlsx'
df_up = pandas.read_excel(input_file, sheet_name='5 uM | 4 h | up', index_col=0)
df_up.shape
# Out:
# (71, 10)

# %%
df_down = pandas.read_excel(input_file, sheet_name='5 uM | 4 h | down', index_col=0)
df_down.shape
# Out:
# (27, 10)

# %%
expression = pandas.concat([df_up, df_down])
expression.shape
# Out:
# (98, 10)

# %%
gene_expression = expression[expression['Biotype'] == 'protein_coding']
print(gene_expression.shape)
gene_expression
# Out:
# (79, 10)
#                  Gene name         Biotype  \
# ENSEMBL
# ENSG00000023171    GRAMD1B  protein_coding
# ENSG00000109321       AREG  protein_coding
# ENSG00000211448       DIO2  protein_coding
# ENSG00000004799       PDK4  protein_coding
# ENSG00000198400      NTRK1  protein_coding
# ...                    ...             ...
# ENSG00000100767      PAPLN  protein_coding
# ENSG00000117228       GBP1  protein_coding
# ENSG00000196872  KIAA1211L  protein_coding
# ENSG00000116717    GADD45A  protein_coding
# ENSG00000139926      FRMD6  protein_coding
#
#                                                       Description  \
# ENSEMBL
# ENSG00000023171                         GRAM domain containing 1B
# ENSG00000109321                                      amphiregulin
# ENSG00000211448                        iodothyronine deiodinase 2
# ENSG00000004799                   pyruvate dehydrogenase kinase 4
# ENSG00000198400           neurotrophic receptor tyrosine kinase 1
# ...

# %%
input_file = '230117_Arnar.lfq.proteins_From_Gudrun.xlsx'
df = pandas.read_excel(input_file)
df.head()
# Out:
#    Protein Group   Top            Accession  Significance  Coverage (%)  \
# 0           1659  True     Q01105|SET_HUMAN         61.25         38.28
# 1           1106  True   P30520|PURA2_HUMAN         45.54         36.18
# 2           5753  True  H3BSJ5|H3BSJ5_HUMAN          9.74         13.78
# 3            189  True   Q92900|RENT1_HUMAN         37.55         49.07
# 4           6355  True  B7ZBQ3|B7ZBQ3_HUMAN         78.08          9.66
#
#    #Peptides  #Unique                                                PTM  \
# 0         11       11                                   Deamidation (NQ)
# 1         14       14  Carbamidomethylation; Deamidation (NQ); Oxidat...
# 2          2        2                                                NaN
# 3         40       40  Carbamidomethylation; Deamidation (NQ); Oxidat...
# 4          1        1                               Carbamidomethylation
#
#    ADRNOR_4H_1_1_2792 Area  ADRNOR_4H_1_2_2793 Area  ...  TNF_4H Area  \
# ...

# %%
print('starting from {} genes'.format(gene_expression.shape[0]))
mapped = 0
for element in gene_expression['Gene name']:
    rule1 = df['Description'].str.contains('GN={} '.format(element))
    rule2 = df['Description'].str.contains('Fragment')
    subset = df[(rule1 == True) & (rule2 == False)]
    a = subset.shape[0]
    if a != 0:
        print('\t gene {} maps to {} proteins'.format(element, a))
        print('\t\t Description: ', gene_expression[gene_expression['Gene name'] == element]['Description'].values[0])
        mapped = mapped + 1

        # retreive mRNA fold-change
        mRNAfc = gene_expression[gene_expression['Gene name'] == element]['log2FC'].values[0]
        print('\t\t mRNAfc {}'.format(mRNAfc))
        
        # retrieve protein fold-change
        labels01 = subset.columns.values[[8, 9]]
        labels02 = subset.columns.values[[10, 11]]
        labels03 = subset.columns.values[[12, 13]]
        
        labels04 = subset.columns.values[[20, 21]]
        labels05 = subset.columns.values[[22, 23]]
        labels06 = subset.columns.values[[24, 25]]        
        
        adr1 = numpy.log2(subset.loc[:, labels01].median(axis=1) + 1)
        adr2 = numpy.log2(subset.loc[:, labels02].median(axis=1) + 1)
        adr3 = numpy.log2(subset.loc[:, labels03].median(axis=1) + 1)
        
        ctl1 = numpy.log2(subset.loc[:, labels04].median(axis=1) + 1)
        ctl2 = numpy.log2(subset.loc[:, labels05].median(axis=1) + 1)
        ctl3 = numpy.log2(subset.loc[:, labels06].median(axis=1) + 1)
        
        ptfc = numpy.median([adr1, adr2, adr3]) - numpy.median([ctl1, ctl2, ctl3])
        #print()
        #print(adr1, adr2, adr3, ctl1, ctl2, ctl3)
        #print(numpy.median([adr1, adr2, adr3]))
        print('\t\t PT fc {}'.format(ptfc))

        ptthreshold = numpy.log2(115/100)

        the_color='black'
        if (mRNAfc >= 1) & (ptfc >= ptthreshold):
            the_color='tab:red'
        if (mRNAfc <= -1) & (ptfc <= -ptthreshold):
            the_color='tab:blue'

        if (mRNAfc >= 1) & (-ptthreshold <= ptfc <= ptthreshold):
            the_color='tab:green'
        if (mRNAfc <= -1) & (-ptthreshold <= ptfc <= ptthreshold):
            the_color='tab:orange'

        if (mRNAfc <= -1) & (ptfc >= ptthreshold):
            the_color='magenta'
        if (mRNAfc >= 1) & (ptfc <= -ptthreshold):
            the_color='c'
        
        matplotlib.pyplot.scatter(mRNAfc, ptfc, s=250, c=the_color, alpha=2/3, edgecolors='none')
        matplotlib.pyplot.text(mRNAfc+0.11, ptfc+0.11/5, element, fontsize=12, color=the_color)
    
print('mapped {} proteins'.format(mapped))

matplotlib.pyplot.xlabel('mRNA change [log2FC]')
matplotlib.pyplot.ylabel('Protein change [log2FC]')
matplotlib.pyplot.xlim([-5, 5])
matplotlib.pyplot.ylim([-1, 1])
matplotlib.pyplot.grid(ls=':', alpha=1/2)
matplotlib.pyplot.show()
# Out:
# starting from 79 genes
# 	 gene CXCR4 maps to 1 proteins
# 		 Description:  C-X-C motif chemokine receptor 4
# 		 mRNAfc 3.6003
# 		 PT fc 0.6111529979202874
# 	 gene THBD maps to 1 proteins
# 		 Description:  thrombomodulin
# 		 mRNAfc 3.389
# 		 PT fc 0.6786207170944021
# 	 gene KIFC1 maps to 1 proteins
# 		 Description:  kinesin family member C1
# 		 mRNAfc 3.1245
# 		 PT fc 0.23619409801283808
# 	 gene RRM2 maps to 1 proteins
# 		 Description:  ribonucleotide reductase regulatory subunit M2
# 		 mRNAfc 2.4995
# 		 PT fc 0.5348241972707974
# 	 gene SLC7A2 maps to 1 proteins
# 		 Description:  solute carrier family 7 member 2
# 		 mRNAfc 2.4033
# 		 PT fc 0.8996250630958116
# 	 gene CHMP1B maps to 1 proteins
# 		 Description:  charged multivesicular body protein 1B
# 		 mRNAfc 2.0502
# 		 PT fc 0.7576962138757395
# 	 gene AKTIP maps to 1 proteins
# 		 Description:  AKT interacting protein
# 		 mRNAfc 1.9186
# 		 PT fc -0.6709580470192851
# 	 gene PDE4D maps to 3 proteins
# ...
